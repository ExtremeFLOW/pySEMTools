# %% [markdown]
# # Processing statistics files
#
# In this example we show how one can use pysemtools to average fields in space.

# %% [markdown]
# #### Import general modules

# %%
# Import required modules
from mpi4py import MPI #equivalent to the use of MPI_init() in C
import matplotlib.pyplot as plt
import numpy as np
import torch

# Get mpi info
comm = MPI.COMM_WORLD

# Hide the log for the notebook. Not recommended when running in clusters as it is better you see what happens
import os
os.environ["PYSEMTOOLS_HIDE_LOG"] = 'false'

# %% [markdown]
# ### Clone the data
#
# Get some data from a public repository

# %%
# Download the data if it does not exist
sem_data_path = "../data/sem_data/"
if not os.path.exists(sem_data_path):
    print("Sem data not found, cloning repository...")
    os.system(f"git clone https://github.com/adperezm/sem_data.git {sem_data_path}")
else:
    print("Sem data found.")
# Out:
# Sem data found.

# %% [markdown]
# ## Create a file name sequence
#
# This file name sequence will be used to read and average the data.

# %%
n_files = 1
folder_path = "../data/"
output_path = "../data/"
file_sequence =[folder_path + f"tc_channel0.f{str(i+1).zfill(5)}" for i in range(n_files)]

# %% [markdown]
# ### Average the file sequence in the homogeneous direction
#
# Simply call the function that performs the average

# %%
from pysemtools.postprocessing.statistics.fld_stats import generate_augmented_field
from pysemtools.datatypes.msh import Mesh
from pysemtools.datatypes.field import FieldRegistry
from pysemtools.datatypes.coef import Coef
from pysemtools.io.ppymech.neksuite import pynekread, pynekwrite

# Read the data
bckend = "torch"
msh = Mesh(comm=comm, bckend=bckend)
pynekread(comm=comm, filename = file_sequence[0], msh = msh, data_dtype=np.float32) # Always define the data type in numpy.

# Generate the coefficients
coef = Coef(msh=msh, comm=comm, bckend=bckend)

for i, fname in enumerate(file_sequence):

    if comm.Get_rank() == 0:
        print("===============================================")
    
    fld = FieldRegistry(comm=comm, bckend=bckend)
    pynekread(comm=comm, filename = fname, fld = fld, data_dtype=np.float32) # Always define the data type in numpy.

    # call the routine
    augmented_fld = generate_augmented_field(comm=comm, msh=msh, fld=fld, coef=coef, dtype=msh.x.dtype)

    # Write the data
    pynekwrite(comm=comm, filename = output_path + f"augmented_field0.f{str(i+1).zfill(5)}", msh = msh.to(comm = comm, bckend="numpy"), fld = augmented_fld.to(comm = comm, bckend="numpy"), wdsz=4)
# Out:
# 2025-12-05 11:33:09,070 - Mesh - INFO - Initializing empty Mesh object.
# 2025-12-05 11:33:09,071 - pynekread - INFO - Reading file: ../data/tc_channel0.f00001
# 2025-12-05 11:33:09,085 - Mesh - INFO - Initializing Mesh object from x,y,z ndarrays.
# 2025-12-05 11:33:09,086 - Mesh - INFO - Initializing common attributes.
# 2025-12-05 11:33:09,087 - Mesh - INFO - Getting vertices
# 2025-12-05 11:33:09,089 - Mesh - INFO - Getting edge centers
# 2025-12-05 11:33:09,098 - Mesh - INFO - Getting facet centers
# 2025-12-05 11:33:09,106 - Mesh - INFO - Mesh object initialized.
# 2025-12-05 11:33:09,107 - Mesh - INFO - Mesh data is of type: torch.float32
# 2025-12-05 11:33:09,108 - Mesh - INFO - Elapsed time: 0.023086983s
# 2025-12-05 11:33:09,109 - pynekread - INFO - File read
# 2025-12-05 11:33:09,110 - pynekread - INFO - Elapsed time: 0.039394515s
# 2025-12-05 11:33:09,112 - Coef - INFO - Initializing Coef object
# 2025-12-05 11:33:09,114 - Coef - INFO - Getting derivative matrices
# 2025-12-05 11:33:09,120 - Coef - INFO - Calculating the components of the jacobian
# 2025-12-05 11:33:09,222 - Coef - INFO - Calculating the jacobian determinant and inverse of the jacobian matrix
# 2025-12-05 11:33:09,231 - Coef - INFO - Calculating the mass matrix
# 2025-12-05 11:33:09,232 - Coef - INFO - Coef object initialized
# 2025-12-05 11:33:09,233 - Coef - INFO - Coef data is of type: torch.float32
# 2025-12-05 11:33:09,234 - Coef - INFO - Elapsed time: 0.121885312s
# ===============================================
# 2025-12-05 11:33:09,236 - Field - INFO - Initializing empty Field object
# 2025-12-05 11:33:09,237 - pynekread - INFO - Reading file: ../data/tc_channel0.f00001
# 2025-12-05 11:33:09,239 - pynekread - INFO - Reading field data
# 2025-12-05 11:33:09,247 - pynekread - INFO - File read
# 2025-12-05 11:33:09,248 - pynekread - INFO - Elapsed time: 0.010527632000000009s
# 2025-12-05 11:33:09,248 - Field - INFO - Initializing empty Field object
# 2025-12-05 11:33:09,260 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,270 - Coef - INFO - done
# 2025-12-05 11:33:09,271 - Coef - INFO - Elapsed time: 0.010644831999999993s
# 2025-12-05 11:33:09,274 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,281 - Coef - INFO - done
# 2025-12-05 11:33:09,283 - Coef - INFO - Elapsed time: 0.008203269999999985s
# 2025-12-05 11:33:09,285 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,291 - Coef - INFO - done
# 2025-12-05 11:33:09,292 - Coef - INFO - Elapsed time: 0.006595053999999989s
# 2025-12-05 11:33:09,293 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,302 - Coef - INFO - done
# 2025-12-05 11:33:09,303 - Coef - INFO - Elapsed time: 0.009549418000000004s
# 2025-12-05 11:33:09,304 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,311 - Coef - INFO - done
# 2025-12-05 11:33:09,312 - Coef - INFO - Elapsed time: 0.0065092380000000005s
# 2025-12-05 11:33:09,313 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,320 - Coef - INFO - done
# 2025-12-05 11:33:09,321 - Coef - INFO - Elapsed time: 0.007904390000000011s
# 2025-12-05 11:33:09,322 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,328 - Coef - INFO - done
# 2025-12-05 11:33:09,329 - Coef - INFO - Elapsed time: 0.006293166000000017s
# 2025-12-05 11:33:09,330 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,336 - Coef - INFO - done
# 2025-12-05 11:33:09,337 - Coef - INFO - Elapsed time: 0.0062802040000000114s
# 2025-12-05 11:33:09,338 - Coef - INFO - Calculating the derivative with respect to physical coordinates
# 2025-12-05 11:33:09,344 - Coef - INFO - done
# 2025-12-05 11:33:09,344 - Coef - INFO - Elapsed time: 0.005224002000000005s
# 2025-12-05 11:33:09,352 - Mesh - INFO - Initializing Mesh object from x,y,z ndarrays.
# 2025-12-05 11:33:09,353 - Mesh - INFO - Initializing common attributes.
# 2025-12-05 11:33:09,354 - Mesh - INFO - Getting vertices
# 2025-12-05 11:33:09,356 - Mesh - INFO - Getting edge centers
# 2025-12-05 11:33:09,365 - Mesh - INFO - Getting facet centers
# 2025-12-05 11:33:09,374 - Mesh - INFO - Mesh object initialized.
# 2025-12-05 11:33:09,375 - Mesh - INFO - Mesh data is of type: float32
# 2025-12-05 11:33:09,376 - Mesh - INFO - Elapsed time: 0.023503425000000022s
# 2025-12-05 11:33:09,377 - Field - INFO - Initializing empty Field object
# 2025-12-05 11:33:09,378 - pynekwrite - INFO - Writing file: ../data/augmented_field0.f00001
# 2025-12-05 11:33:09,437 - pynekwrite - INFO - Elapsed time: 0.05894913299999999s

# %% [markdown]
# That's it! check your file in, e.g., Visit or paraview and check how it turned out!
