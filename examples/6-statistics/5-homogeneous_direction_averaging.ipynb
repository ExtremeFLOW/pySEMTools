# %% [markdown]
# # Processing statistics files
#
# In this example we show how one can use pysemtools to average fields in space.

# %% [markdown]
# #### Import general modules

# %%
# Import required modules
from mpi4py import MPI #equivalent to the use of MPI_init() in C
import matplotlib.pyplot as plt
import numpy as np

# Get mpi info
comm = MPI.COMM_WORLD

# Hide the log for the notebook. Not recommended when running in clusters as it is better you see what happens
import os
os.environ["PYSEMTOOLS_HIDE_LOG"] = 'false'

# %% [markdown]
# ### Clone the data
#
# Get some data from a public repository

# %%
# Download the data if it does not exist
sem_data_path = "../data/sem_data/"
if not os.path.exists(sem_data_path):
    print("Sem data not found, cloning repository...")
    os.system(f"git clone https://github.com/adperezm/sem_data.git {sem_data_path}")
else:
    print("Sem data found.")
# Out:
# Sem data found.

# %% [markdown]
# ## Create a file name sequence
#
# This file name sequence will be used to read and average the data.

# %%
n_files = 1
folder_path = "../data/sem_data/statistics/channel_nelv_5000/"
file_sequence =[folder_path + f"batch_mean_field0.f{str(i).zfill(5)}" for i in range(n_files)]

# %% [markdown]
# ### Average the file sequence in the homogeneous direction
#
# Simply call the function that performs the average

# %%
from pysemtools.postprocessing.statistics.space_averaging import space_average_field_files

# call the routine
space_average_field_files(comm, file_sequence=file_sequence, output_folder="./", dtype=np.single, rel_tol = 1e-5, output_word_size= 4, write_mesh=True, homogeneous_dir="z", output_in_3d=False)
# Out:
# 2025-12-05 11:29:35,537 - space_average_field_files - INFO - Averaging field files in sequence: ['../data/sem_data/statistics/channel_nelv_5000/batch_mean_field0.f00000']
# 2025-12-05 11:29:35,538 - space_average_field_files - INFO - Reading the mesh from the first file in the sequence
# 2025-12-05 11:29:35,539 - space_average_field_files - INFO - Output files will be saved in: ./
# 2025-12-05 11:29:35,539 - Mesh - INFO - Initializing empty Mesh object.
# 2025-12-05 11:29:35,540 - pynekread - INFO - Reading file: ../data/sem_data/statistics/channel_nelv_5000/batch_mean_field0.f00000
# 2025-12-05 11:29:35,569 - Mesh - INFO - Initializing Mesh object from x,y,z ndarrays.
# 2025-12-05 11:29:35,570 - Mesh - INFO - Initializing common attributes.
# 2025-12-05 11:29:35,571 - Mesh - INFO - Getting vertices
# 2025-12-05 11:29:35,573 - Mesh - INFO - Getting edge centers
# 2025-12-05 11:29:35,650 - Mesh - INFO - Getting facet centers
# 2025-12-05 11:29:35,701 - Mesh - INFO - Mesh object initialized.
# 2025-12-05 11:29:35,702 - Mesh - INFO - Mesh data is of type: float32
# 2025-12-05 11:29:35,703 - Mesh - INFO - Elapsed time: 0.13361820099999022s
# 2025-12-05 11:29:35,704 - pynekread - INFO - File read
# 2025-12-05 11:29:35,704 - pynekread - INFO - Elapsed time: 0.16428677700002936s
# 2025-12-05 11:29:35,706 - space_average_field_files - INFO - Initializing coefficients
# 2025-12-05 11:29:35,708 - Coef - INFO - Initializing Coef object
# 2025-12-05 11:29:35,709 - Coef - INFO - Getting derivative matrices
# 2025-12-05 11:29:35,815 - Coef - INFO - Calculating the components of the jacobian
# 2025-12-05 11:29:35,901 - Coef - INFO - Calculating the jacobian determinant and inverse of the jacobian matrix
# 2025-12-05 11:29:35,950 - Coef - INFO - Calculating the mass matrix
# 2025-12-05 11:29:35,952 - Coef - INFO - Coef object initialized
# 2025-12-05 11:29:35,953 - Coef - INFO - Coef data is of type: float32
# 2025-12-05 11:29:35,953 - Coef - INFO - Elapsed time: 0.24588868799997954s
# 2025-12-05 11:29:35,954 - space_average_field_files - INFO - Averaging in the direction: z
# 2025-12-05 11:29:35,955 - space_average_field_files - INFO - Identifying unique cross-sections in each rank separately
# 2025-12-05 11:29:35,978 - space_average_field_files - INFO - Identifying which rank will take charge of the 2D elements
# 2025-12-05 11:29:35,980 - space_average_field_files - WARNING - This might be slow...
# 2025-12-05 11:29:35,980 - space_average_field_files - WARNING - It might be slower with many ranks...
# 2025-12-05 11:29:35,980 - space_average_field_files - WARNING - Consider using only as many as necesary for data to fit in memory
# 2025-12-05 11:29:36,053 - space_average_field_files - INFO - done!
# 2025-12-05 11:29:36,054 - space_average_field_files - INFO - Elapsed time: 0.07308071500000324s
# 2025-12-05 11:29:36,054 - space_average_field_files - INFO - Mapping the indices of the original elements to those of the unique elements in the specified direction
# 2025-12-05 11:29:36,297 - space_average_field_files - INFO - Getting 2D slices
# 2025-12-05 11:29:36,380 - space_average_field_files - INFO - Verifying averaging
# 2025-12-05 11:29:36,400 - space_average_field_files - INFO - Averaging test passed: True
# 2025-12-05 11:29:36,401 - space_average_field_files - INFO - Creating 2D mesh object on ranks that have them
# 2025-12-05 11:29:36,402 - Mesh - INFO - Initializing Mesh object from x,y,z ndarrays.
# 2025-12-05 11:29:36,402 - Mesh - INFO - Initializing common attributes.
# 2025-12-05 11:29:36,403 - Mesh - INFO - Getting vertices
# 2025-12-05 11:29:36,403 - Mesh - INFO - Getting edge centers
# 2025-12-05 11:29:36,406 - Mesh - INFO - Facet centers not available for 2D
# 2025-12-05 11:29:36,406 - Mesh - INFO - Mesh object initialized.
# 2025-12-05 11:29:36,406 - Mesh - INFO - Mesh data is of type: float32
# 2025-12-05 11:29:36,407 - Mesh - INFO - Elapsed time: 0.0049296060000187936s
# 2025-12-05 11:29:36,408 - Field - INFO - Initializing empty Field object
# 2025-12-05 11:29:36,410 - pynekwrite - INFO - Writing file: ./2dcoordinates0.f00000
# 2025-12-05 11:29:36,412 - pynekwrite - INFO - Elapsed time: 0.002028196999958709s
# =================================================================================================
# 2025-12-05 11:29:36,412 - Field - INFO - Initializing empty Field object
# 2025-12-05 11:29:36,413 - space_average_field_files - INFO - Starting to go through the files in the index:
# 2025-12-05 11:29:36,413 - space_average_field_files - INFO - Reading file ../data/sem_data/statistics/channel_nelv_5000/batch_mean_field0.f00000
# 2025-12-05 11:29:36,414 - pynekread - INFO - Reading file: ../data/sem_data/statistics/channel_nelv_5000/batch_mean_field0.f00000
# 2025-12-05 11:29:36,416 - pynekread - INFO - Reading field data
# 2025-12-05 11:29:36,441 - pynekread - INFO - File read
# 2025-12-05 11:29:36,442 - pynekread - INFO - Elapsed time: 0.02827252999998109s
# 2025-12-05 11:29:36,443 - space_average_field_files - INFO - Averaging the fields in the specified direction
# 2025-12-05 11:29:36,575 - space_average_field_files - INFO - z velocity field found in the file and output in 3D is not requested. Saving z velocity as the last scalar
# 2025-12-05 11:29:36,621 - space_average_field_files - INFO - Averaging finished, writing to file ./z_avg_batch_mean_field0.f00000
# 2025-12-05 11:29:36,622 - pynekwrite - INFO - Writing file: ./z_avg_batch_mean_field0.f00000
# 2025-12-05 11:29:36,623 - pynekwrite - INFO - Elapsed time: 0.001674507000018366s
# 2025-12-05 11:29:36,624 - space_average_field_files - INFO - Run finished
# 2025-12-05 11:29:36,625 - space_average_field_files - INFO - Elapsed time: 0.2117030460000251s

# %% [markdown]
# That's it! check your file in, e.g., Visit or paraview and check how it turned out!
